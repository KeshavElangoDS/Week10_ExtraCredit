# %% [markdown]
# ## Extra Credit - GIS Mapping

# %% [markdown]
# This Notebook is about the Band `Neffex` tour data from 2018 till 2023.

# %% [markdown]
#  - Opening the tour data for `Neffex` band across United States.
#  - The data is taken from the website [ConcertArchive](https://www.concertarchives.org/bands/neffex?page=1#concert-table)

# %%
import geopandas as gpd
import geoviews as gv
import holoviews as hv
import hvplot.pandas
import pandas as pd
import panel as pn
gv.extension('bokeh')
hv.extension('bokeh')
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# We open the file and read the and convert it into a dataframe

# %%
with open('data/neffex_data.dat') as data_handle:
    tour = data_handle.read()
print(tour)
# Out:
# Dec 17, 2023  -  Hawthorne Theatre - Portland, Oregon, United States
# Dec 16, 2023  -  Hawthorne Theatre - Portland, Oregon, United States
# Dec 15, 2023  -  The Rebel Lounge - Phoenix, Arizona, United States
# Dec 14, 2023  -  The Rebel Lounge - Phoenix, Arizona, United States
# Dec 07, 2023  -  Lost Lake Lounge - Denver, Colorado, United States
# Dec 06, 2023  -  The Roxy Theatre - West Hollywood, California, United States
# Dec 02, 2023  -  Skyway Theatre - Minneapolis, Minnesota, United States
# Dec 01, 2023  -  Lincoln Hall - Chicago, Illinois, United States
# Nov 19, 2023  -  Mercury Lounge - New York, New York, United States
# Nov 17, 2023  -  Mercury Lounge - New York, New York, United States
# Nov 16, 2023  -  DC9 Nightclub - Washington, D.C., United States
# Nov 12, 2023  -  Mercury Lounge - New York, New York, United States
# Nov 11, 2023  -  DC9 Nightclub - Washington, D.C., United States
# Mar 14, 2020  -  Subterranean - Chicago, Illinois, United States
# Sep 12, 2019 - Troubadour - West Hollywood, California, United States
# Jun 15, 2018 - The Roxy Theatre - West Hollywood, California, United States

# %%
tour_data = [ line.split(' - ') for line in tour.split('\n')]
tour_df = pd.DataFrame(tour_data, columns = ['Date', 'Venue', 'City'])
tour_df
# Out:
#              Date               Venue  \
# 0   Dec 17, 2023    Hawthorne Theatre
# 1   Dec 16, 2023    Hawthorne Theatre
# 2   Dec 15, 2023     The Rebel Lounge
# 3   Dec 14, 2023     The Rebel Lounge
# 4   Dec 07, 2023     Lost Lake Lounge
# 5   Dec 06, 2023     The Roxy Theatre
# 6   Dec 02, 2023       Skyway Theatre
# 7   Dec 01, 2023         Lincoln Hall
# 8   Nov 19, 2023       Mercury Lounge
# 9   Nov 17, 2023       Mercury Lounge
# 10  Nov 16, 2023        DC9 Nightclub
# 11  Nov 12, 2023       Mercury Lounge
# 12  Nov 11, 2023        DC9 Nightclub
# 13  Mar 14, 2020         Subterranean
# 14   Sep 12, 2019          Troubadour
# 15   Jun 15, 2018    The Roxy Theatre
#
#                                          City
# 0             Portland, Oregon, United States
# 1             Portland, Oregon, United States
# 2             Phoenix, Arizona, United States
# 3             Phoenix, Arizona, United States
# 4             Denver, Colorado, United States
# 5   West Hollywood, California, United States
# 6       Minneapolis, Minnesota, United States
# 7            Chicago, Illinois, United States
# 8           New York, New York, United States
# 9           New York, New York, United States
# 10            Washington, D.C., United States
# 11          New York, New York, United States
# 12            Washington, D.C., United States
# 13           Chicago, Illinois, United States
# 14  West Hollywood, California, United States
# 15  West Hollywood, California, United States

# %%
tour_df.iloc[0,1]
# Out:
# ' Hawthorne Theatre'

# %% [markdown]
# As we have trailing whitespaces, the applymap function is applied to each cell of the dataframe to remove the whitespaces.

# %%
tour_df = tour_df.map(lambda x: x.strip())
print(tour_df.iloc[0,0])
print(tour_df.iloc[0,1])
print(tour_df.iloc[0,2])
tour_df
# Out:
# Dec 17, 2023
# Hawthorne Theatre
# Portland, Oregon, United States
#             Date              Venue                                       City
# 0   Dec 17, 2023  Hawthorne Theatre            Portland, Oregon, United States
# 1   Dec 16, 2023  Hawthorne Theatre            Portland, Oregon, United States
# 2   Dec 15, 2023   The Rebel Lounge            Phoenix, Arizona, United States
# 3   Dec 14, 2023   The Rebel Lounge            Phoenix, Arizona, United States
# 4   Dec 07, 2023   Lost Lake Lounge            Denver, Colorado, United States
# 5   Dec 06, 2023   The Roxy Theatre  West Hollywood, California, United States
# 6   Dec 02, 2023     Skyway Theatre      Minneapolis, Minnesota, United States
# 7   Dec 01, 2023       Lincoln Hall           Chicago, Illinois, United States
# 8   Nov 19, 2023     Mercury Lounge          New York, New York, United States
# 9   Nov 17, 2023     Mercury Lounge          New York, New York, United States
# 10  Nov 16, 2023      DC9 Nightclub            Washington, D.C., United States
# 11  Nov 12, 2023     Mercury Lounge          New York, New York, United States
# 12  Nov 11, 2023      DC9 Nightclub            Washington, D.C., United States
# 13  Mar 14, 2020       Subterranean           Chicago, Illinois, United States
# 14  Sep 12, 2019         Troubadour  West Hollywood, California, United States
# 15  Jun 15, 2018   The Roxy Theatre  West Hollywood, California, United States

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="MyApp")

# %% [markdown]
# We use the Nomanatim function from `geopy.geocoders` to obtain the latitude and longitude

# %%
def get_location(row):
    location = geolocator.geocode(row.City)
    return location.latitude, location.longitude

tour_df[['Latitude','Longitude']] = tour_df.apply(get_location, axis=1, result_type = 'expand')
tour_df
# Out:
#             Date              Venue  \
# 0   Dec 17, 2023  Hawthorne Theatre
# 1   Dec 16, 2023  Hawthorne Theatre
# 2   Dec 15, 2023   The Rebel Lounge
# 3   Dec 14, 2023   The Rebel Lounge
# 4   Dec 07, 2023   Lost Lake Lounge
# 5   Dec 06, 2023   The Roxy Theatre
# 6   Dec 02, 2023     Skyway Theatre
# 7   Dec 01, 2023       Lincoln Hall
# 8   Nov 19, 2023     Mercury Lounge
# 9   Nov 17, 2023     Mercury Lounge
# 10  Nov 16, 2023      DC9 Nightclub
# 11  Nov 12, 2023     Mercury Lounge
# 12  Nov 11, 2023      DC9 Nightclub
# 13  Mar 14, 2020       Subterranean
# 14  Sep 12, 2019         Troubadour
# 15  Jun 15, 2018   The Roxy Theatre
#
#                                          City   Latitude   Longitude
# 0             Portland, Oregon, United States  45.520247 -122.674194
# 1             Portland, Oregon, United States  45.520247 -122.674194
# 2             Phoenix, Arizona, United States  33.448437 -112.074141
# 3             Phoenix, Arizona, United States  33.448437 -112.074141
# 4             Denver, Colorado, United States  39.739236 -104.984862
# 5   West Hollywood, California, United States  34.092301 -118.369289
# 6       Minneapolis, Minnesota, United States  44.977300  -93.265469
# 7            Chicago, Illinois, United States  41.875562  -87.624421
# 8           New York, New York, United States  40.712728  -74.006015
# 9           New York, New York, United States  40.712728  -74.006015
# 10            Washington, D.C., United States  38.895037  -77.036543
# 11          New York, New York, United States  40.712728  -74.006015
# 12            Washington, D.C., United States  38.895037  -77.036543
# 13           Chicago, Illinois, United States  41.875562  -87.624421
# 14  West Hollywood, California, United States  34.092301 -118.369289
# 15  West Hollywood, California, United States  34.092301 -118.369289

# %% [markdown]
# The `Geopandas` module helps to create a point with latitude and longitude which further helps with correlating better with the Geoviews module.

# %%
geo_tour = gpd.GeoDataFrame(
    tour_df, geometry=gpd.points_from_xy(tour_df.Longitude, tour_df.Latitude)
)
geo_tour
# Out:
#             Date              Venue  \
# 0   Dec 17, 2023  Hawthorne Theatre
# 1   Dec 16, 2023  Hawthorne Theatre
# 2   Dec 15, 2023   The Rebel Lounge
# 3   Dec 14, 2023   The Rebel Lounge
# 4   Dec 07, 2023   Lost Lake Lounge
# 5   Dec 06, 2023   The Roxy Theatre
# 6   Dec 02, 2023     Skyway Theatre
# 7   Dec 01, 2023       Lincoln Hall
# 8   Nov 19, 2023     Mercury Lounge
# 9   Nov 17, 2023     Mercury Lounge
# 10  Nov 16, 2023      DC9 Nightclub
# 11  Nov 12, 2023     Mercury Lounge
# 12  Nov 11, 2023      DC9 Nightclub
# 13  Mar 14, 2020       Subterranean
# 14  Sep 12, 2019         Troubadour
# 15  Jun 15, 2018   The Roxy Theatre
#
#                                          City   Latitude   Longitude  \
# 0             Portland, Oregon, United States  45.520247 -122.674194
# 1             Portland, Oregon, United States  45.520247 -122.674194
# 2             Phoenix, Arizona, United States  33.448437 -112.074141
# 3             Phoenix, Arizona, United States  33.448437 -112.074141
# 4             Denver, Colorado, United States  39.739236 -104.984862
# 5   West Hollywood, California, United States  34.092301 -118.369289
# 6       Minneapolis, Minnesota, United States  44.977300  -93.265469
# 7            Chicago, Illinois, United States  41.875562  -87.624421
# 8           New York, New York, United States  40.712728  -74.006015
# 9           New York, New York, United States  40.712728  -74.006015
# 10            Washington, D.C., United States  38.895037  -77.036543
# 11          New York, New York, United States  40.712728  -74.006015
# 12            Washington, D.C., United States  38.895037  -77.036543
# 13           Chicago, Illinois, United States  41.875562  -87.624421
# 14  West Hollywood, California, United States  34.092301 -118.369289
# 15  West Hollywood, California, United States  34.092301 -118.369289
#
#                        geometry
# 0   POINT (-122.67419 45.52025)
# 1   POINT (-122.67419 45.52025)
# 2   POINT (-112.07414 33.44844)
# 3   POINT (-112.07414 33.44844)
# 4   POINT (-104.98486 39.73924)
# 5   POINT (-118.36929 34.09230)
# 6    POINT (-93.26547 44.97730)
# 7    POINT (-87.62442 41.87556)
# 8    POINT (-74.00602 40.71273)
# 9    POINT (-74.00602 40.71273)
# 10   POINT (-77.03654 38.89504)
# 11   POINT (-74.00602 40.71273)
# 12   POINT (-77.03654 38.89504)
# 13   POINT (-87.62442 41.87556)
# 14  POINT (-118.36929 34.09230)
# 15  POINT (-118.36929 34.09230)

# %% [markdown]
# Image of `ESRI` world map from `geoviews` under tile_sources

# %%
esri_world = gv.tile_sources.EsriImagery().opts(
    height=500,
    width=700
)
esri_world
# Out:
# :WMTS   [Longitude,Latitude]

# %%
dir(gv.tile_sources)
# Out:
# ['CartoDark',
#  'CartoEco',
#  'CartoLight',
#  'CartoMidnight',
#  'ESRI',
#  'EsriAntarcticImagery',
#  'EsriArcticImagery',
#  'EsriArcticOceanBase',
#  'EsriArcticOceanReference',
#  'EsriDelormeWorldBaseMap',
#  'EsriImagery',
#  'EsriNatGeo',
#  'EsriOceanBase',
#  'EsriOceanReference',
#  'EsriReference',
#  'EsriTerrain',
#  'EsriUSATopo',
#  'EsriWorldBoundariesAndPlaces',
#  'EsriWorldBoundariesAndPlacesAlternate',
#  'EsriWorldDarkGrayBase',
#  'EsriWorldDarkGrayReference',
#  'EsriWorldHillshade',
#  'EsriWorldHillshadeDark',
#  'EsriWorldLightGrayBase',
#  'EsriWorldLightGrayReference',
#  'EsriWorldNavigationCharts',
#  'EsriWorldPhysical',
#  'EsriWorldShadedRelief',
#  'EsriWorldStreetMap',
#  'EsriWorldTopo',
#  'EsriWorldTransportation',
#  'OSM',
#  'OpenTopoMap',
#  'StamenLabels',
#  'StamenLabelsRetina',
#  'StamenTerrain',
#  'StamenTerrainRetina',
#  'StamenToner',
#  'StamenTonerBackground',
#  'StamenTonerBackgroundRetina',
#  'StamenTonerRetina',
#  'StamenWatercolor',
#  'WMTS',
#  '_ATTRIBUTIONS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'stamen_sources',
#  'tile_sources']

# %% [markdown]
# Image of `Topographic world map` world map from `geoviews` under tile_sources

# %%
open_topo_world = gv.tile_sources.OpenTopoMap().opts(
    height=500,
    width=700
)
open_topo_world
# Out:
# :WMTS   [Longitude,Latitude]

# %%
continental_usa_lon = [-124.736342, -66.945392]
continental_usa_lat = [24.521208, 49.382808]

# %%
points = gv.Points(geo_tour).opts(
    size = 5, 
    color = 'Date', 
    show_legend=False, 
    tools=['hover']
)

path = gv.Path([geo_tour]).opts(
    color = 'black',
    line_width=2
)

(esri_world * points * path).opts(
    title = 'Neffex Tour 2018 - 2023',
    width = 700,
    height = 500
)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (Date,Venue,City,Latitude,Longitude)
#    .Path.I   :Path   [Longitude,Latitude]

# %% [markdown]
# ## Plotting the Tour data along with the path

# %% [markdown]
# Here teh ESRI world map is used for plotting the tour data

# %%
points = gv.Points(geo_tour).opts(
    size = 5, 
    color = 'Date', 
    show_legend=False, 
    tools=['hover']
)

path = gv.Path([geo_tour]).opts(
    color = 'black',
    line_width=2
)

(esri_world * points * path ) .opts(
    title = 'Neffex Tour 2018 - 2023',
    width = 700,
    height = 500
)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (Date,Venue,City,Latitude,Longitude)
#    .Path.I   :Path   [Longitude,Latitude]

# %% [markdown]
# ## Plotting tour data with widget to control Marker size

# %% [markdown]
# Here the topographic map is used as it has a `better color contrast` along with the `cities highlighted` when zoomed in.

# %%
scatter_tour = gv.Points(geo_tour)

marker_size_slider = pn.widgets.IntSlider(name='Marker Size', start=5, end=10, step=1)

path = gv.Path([geo_tour]).opts(
    color = 'black',
    line_width=2
)

# create dynamic function for 
@pn.depends(marker_size=marker_size_slider)
def plot_all_tour_location(marker_size):
    return (open_topo_world * path * scatter_tour.opts(
        size=marker_size,
        color='Date',
        alpha=0.75,
        tools=['hover'],
        show_legend= False
    )).opts(
        title='Neffex Tour 2018 - 2023',
        height=500,
        width=700
    )

pn.Column(
    marker_size_slider,
    hv.DynamicMap(plot_all_tour_location)
)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'d08f2c38-bbb3-477b-977c-67be9f8392ca': {'version…
